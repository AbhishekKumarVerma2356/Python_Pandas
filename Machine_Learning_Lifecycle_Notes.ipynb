# %% [markdown]
# # Machine Learning Lifecycle
#
# ```
# Data Gathering
# ↓
# Store in Pandas DataFrame
# ↓
# Data Exploration
# ↓
# Data Cleaning
# ↓
# EDA
# ↓
# Data Preprocessing
# ↓
# Train ML Model
# ↓
# Model Evaluation
# ↓
# Prediction
# ```

# %% [markdown]
# ## Step 1: Data Gathering
#
# Collect data from CSV, Excel, Database, API, Web Scraping.
# Store it in a Pandas DataFrame.

# %%
import pandas as pd
# df = pd.read_csv('students.csv')

# %% [markdown]
# ## Step 2: Data Exploration
#
# Understand shape, columns, types and statistics.

# %%
# df.head()
# df.info()
# df.describe()

# %% [markdown]
# ## Step 3: Data Cleaning
#
# Handle missing values, duplicates and incorrect types.

# %%
# df.drop_duplicates()
# df.fillna(0)

# %% [markdown]
# ## Step 4: Exploratory Data Analysis (EDA)
#
# Use Pandas, Matplotlib and Seaborn to visualize data.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Step 5: Data Preprocessing
#
# Encoding, Scaling and Train-Test Split.

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Step 6: Machine Learning Model
#
# Train a model.

# %%
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# ## Step 7: Model Evaluation
#
# Evaluate using Accuracy, Precision, Recall, F1.

# %%
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## Step 8: Prediction
#
# Predict on new data.

# %%
# predictions = model.predict(X_test)
