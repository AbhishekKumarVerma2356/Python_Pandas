# %% [markdown]
# # **Pandas**

# %% [markdown]
# ### **Pandas** is Powerful Library used for Data Manipulation and Analysis. It helps us to work with data in Tabular Format, just like how we deal with data and spreadsheet in excel or database.
